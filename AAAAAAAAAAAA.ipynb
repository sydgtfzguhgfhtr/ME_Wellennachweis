# %%
from Klassen import Welle

test = Welle("Test", 0, 195)

test.set_geometrie(
    ((0,10),
    (40,10),
    (40,20),
    (80,20),
    (80,27.5),
    (160,27.5),
    (160,15),
    (195,15))
)

test.set_Kraft(3500, "r", 20, -test.d(20)/2)
test.set_Kraft(-4500, "r", 135, -test.d(135)/2, 0)

test.lagerkräfte_berechnen()

test.plot()

# %%
import matplotlib.pyplot as plt

print(test.Verformung_())

plt.plot(test.Verformung_())
plt.grid(True)
plt.show()
# Out:
# <function Welle.Verformung_.<locals>.F_ers_x at 0x000002D41A753C70>
# None
# <function Welle.Verformung_.<locals>.F_ers_x at 0x000002D41A753C70>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Nadine\Documents\Studium\Studium\1234567890\ME_Wellen\ME_Wellennachweis\AAAAAAAAAAAA.ipynb Cell 2 in 5
#       <a href='vscode-notebook-cell:/c%3A/Users/Nadine/Documents/Studium/Studium/1234567890/ME_Wellen/ME_Wellennachweis/AAAAAAAAAAAA.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/c%3A/Users/Nadine/Documents/Studium/Studium/1234567890/ME_Wellen/ME_Wellennachweis/AAAAAAAAAAAA.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> print(test.Verformung_())
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Nadine/Documents/Studium/Studium/1234567890/ME_Wellen/ME_Wellennachweis/AAAAAAAAAAAA.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> plt.plot(test.Verformung_())
#       <a href='vscode-notebook-cell:/c%3A/Users/Nadine/Documents/Studium/Studium/1234567890/ME_Wellen/ME_Wellennachweis/AAAAAAAAAAAA.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> plt.grid(True)
#       <a href='vscode-notebook-cell:/c%3A/Users/Nadine/Documents/Studium/Studium/1234567890/ME_Wellen/ME_Wellennachweis/AAAAAAAAAAAA.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> plt.show()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\pyplot.py:2730, in plot(scalex, scaley, data, *args, **kwargs)
#    2728 @_copy_docstring_and_deprecators(Axes.plot)
#    2729 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2730     return gca().plot(
#    2731         *args, scalex=scalex, scaley=scaley,
#    2732         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\axes\_axes.py:1662, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1419 """
#    1420 Plot y versus x as lines and/or markers.
#    1421
#    (...)
#    1659 (``'green'``) or hex strings (``'#008000'``).
#    1660 """
#    1661 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1662 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1663 for line in lines:
#    1664     self.add_line(line)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\axes\_base.py:465, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     462 # Don't allow any None value; these would be up-converted to one
#     463 # element array of None which causes problems downstream.
#     464 if any(v is None for v in tup):
# --> 465     raise ValueError("x, y, and format string must not be None")
#     467 kw = {}
#     468 for prop_name, val in zip(('linestyle', 'marker', 'color'),
#     469                           (linestyle, marker, color)):
#
# ValueError: x, y, and format string must not be None
