# %%
from wellen import Welle,Welle_Absatz,Werkstoff
Werkstoff.aus_datenbank_laden()
# Out:
# Warnung: Module 'cadquery' nicht gefunden. 3D Export ist nicht verfügbar.

# %%
Beispielwelle = Welle("Beispiel",0,100,Werkstoff.Werkstoffe['S235JR'],Oberflächenverfestigung="nein")
Beispielwelle.set_geometrie([[0,25],[100,25]])
Beispielwelle.set_Kraft(1000,"r",50)
Beispielwelle.set_Kraft(1000,"a",50,25)
Beispielwelle.lagerkräfte_berechnen()
Beispielwelle.verformung_berechnen()
Beispielwelle.plot()

# %%
Beispielwelle.plot_spannungen()
